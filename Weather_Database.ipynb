# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from config import weather_api_key
from citipy import citipy
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
#testing
london_data = []
england = "london"
london_url = "http://api.openweathermap.org/data/2.5/weather?q=" + england + "&units=imperial" + "&appid=" + weather_api_key

london_weather = requests.get(london_url).json()
london_weather
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 52.75,
#   'feels_like': 50.27,
#   'temp_min': 51.01,
#   'temp_max': 55,
#   'pressure': 1020,
#   'humidity': 54},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 130},
#  'clouds': {'all': 100},
#  'dt': 1618862827,
#  'sys': {'type': 1,
#   'id': 1414,
#   'country': 'GB',
#   'sunrise': 1618808150,
#   'sunset': 1618858977},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
#finally found index method for description
london_data = []
england = "london"
london_url = "http://api.openweathermap.org/data/2.5/weather?q=" + england + "&units=imperial" + "&appid=" + weather_api_key

london_weather = requests.get(london_url).json()

london_lat = london_weather["coord"]["lat"]
london_id = london_weather["weather"][0]["description"]
london_id
# Out:
# 'overcast clouds'

# %%
#testing
london_data = []
england = "london"
london_url = "http://api.openweathermap.org/data/2.5/weather?q=" + england + "&units=imperial" + "&appid=" + weather_api_key

london_weather = requests.get(london_url).json()

london_lat = london_weather["coord"]["lat"]
#city_lng = city_weather["coord"]["lon"]
london_max_temp = london_weather["main"]["temp_max"]
#city_humidity = city_weather["main"]["humidity"]
#city_clouds = city_weather["clouds"]["all"]
#city_wind = city_weather["wind"]["speed"]
london_description = london_weather["weather"][0]["description"]

print(london_lat)

london_data.append({"City": "London",
                    "Lat": london_lat,
                    "Max Temp": london_max_temp,
                    "Weather Description": london_description})
london_data
# Out:
# 51.5085
# [{'City': 'London',
#   'Lat': 51.5085,
#   'Max Temp': 54,
#   'Weather Description': 'overcast clouds'}]

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = "http://api.openweathermap.org/data/2.5/weather?q=" + city.replace(" ", "+") + "&units=imperial" + "&appid=" + weather_api_key

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
   
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | ornskoldsvik
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | kaseda
# Processing Record 5 of Set 1 | hovd
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | margate
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | poya
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 1 | bouillante
# Processing Record 13 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | emba
# Processing Record 17 of Set 1 | rongcheng
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | petatlan
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | putina
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | mecca
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | panalingaan
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | aquiraz
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 1 | borovoy
# Processing Record 39 of Set 1 | jardim
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | papara
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | kazachinskoye
# Processing Record 2 of Set 2 | olinda
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | basqal
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | te anau
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | guerrero negro
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | waddan
# Processing Record 19 of Set 2 | dabuleni
# Processing Record 20 of Set 2 | walla walla
# Processing Record 21 of Set 2 | lidkoping
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | paralimni
# Processing Record 24 of Set 2 | aksu
# Processing Record 25 of Set 2 | campbell river
# Processing Record 26 of Set 2 | salta
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | chernyshkovskiy
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | komsomolskiy
# Processing Record 32 of Set 2 | wawa
# Processing Record 33 of Set 2 | el mante
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | xingyi
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | trairi
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | katsuura
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | itarema
# Processing Record 45 of Set 2 | araxa
# Processing Record 46 of Set 2 | samarai
# Processing Record 47 of Set 2 | tete
# Processing Record 48 of Set 2 | dakoro
# Processing Record 49 of Set 2 | pacific grove
# Processing Record 50 of Set 2 | parrita
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | honiara
# Processing Record 4 of Set 3 | hun
# Processing Record 5 of Set 3 | latung
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | sorland
# Processing Record 8 of Set 3 | praia da vitoria
# Processing Record 9 of Set 3 | gamba
# Processing Record 10 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 3 | chunhuhub
# Processing Record 12 of Set 3 | bilma
# Processing Record 13 of Set 3 | whitley bay
# Processing Record 14 of Set 3 | warangal
# Processing Record 15 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 3 | anadyr
# Processing Record 17 of Set 3 | akdagmadeni
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | natalio
# Processing Record 21 of Set 3 | constitucion
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | hede
# Processing Record 24 of Set 3 | thano bula khan
# City not found. Skipping...
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 3 | camacha
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | sao joao da barra
# Processing Record 30 of Set 3 | okha
# Processing Record 31 of Set 3 | leh
# Processing Record 32 of Set 3 | santa teresa
# Processing Record 33 of Set 3 | sucua
# Processing Record 34 of Set 3 | machaneng
# Processing Record 35 of Set 3 | mayskiy
# Processing Record 36 of Set 3 | luena
# Processing Record 37 of Set 3 | bosaso
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | yei
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | mount isa
# Processing Record 42 of Set 3 | hermanus
# Processing Record 43 of Set 3 | nunchia
# Processing Record 44 of Set 3 | tessalit
# Processing Record 45 of Set 3 | amapa
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | hualmay
# Processing Record 48 of Set 3 | puerto colombia
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | necochea
# Processing Record 4 of Set 4 | tonder
# Processing Record 5 of Set 4 | bibbiena
# Processing Record 6 of Set 4 | taltal
# Processing Record 7 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 4 | shelburne
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | zlobin
# Processing Record 11 of Set 4 | takapau
# Processing Record 12 of Set 4 | sechura
# Processing Record 13 of Set 4 | hambantota
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | birjand
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | capreol
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | qaanaaq
# Processing Record 20 of Set 4 | havoysund
# Processing Record 21 of Set 4 | urusha
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | port-gentil
# Processing Record 24 of Set 4 | qaqortoq
# Processing Record 25 of Set 4 | chanika
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | cayenne
# Processing Record 28 of Set 4 | domoni
# Processing Record 29 of Set 4 | kinablangan
# Processing Record 30 of Set 4 | soloneshnoye
# Processing Record 31 of Set 4 | la palma
# Processing Record 32 of Set 4 | katherine
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | barwala
# Processing Record 35 of Set 4 | bathsheba
# Processing Record 36 of Set 4 | cidreira
# Processing Record 37 of Set 4 | alice springs
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | itoman
# Processing Record 40 of Set 4 | taoudenni
# Processing Record 41 of Set 4 | icatu
# Processing Record 42 of Set 4 | longyearbyen
# Processing Record 43 of Set 4 | kismayo
# Processing Record 44 of Set 4 | shepsi
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 4 | paita
# Processing Record 48 of Set 4 | vao
# Processing Record 49 of Set 4 | buchanan
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | orocue
# Processing Record 2 of Set 5 | yulara
# Processing Record 3 of Set 5 | mayang imphal
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | jaranwala
# Processing Record 6 of Set 5 | hue
# Processing Record 7 of Set 5 | ancud
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 5 | aswan
# Processing Record 11 of Set 5 | aklavik
# Processing Record 12 of Set 5 | itzehoe
# Processing Record 13 of Set 5 | axim
# Processing Record 14 of Set 5 | northam
# Processing Record 15 of Set 5 | saint-pierre
# Processing Record 16 of Set 5 | berlevag
# Processing Record 17 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 18 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 5 | chipinge
# Processing Record 20 of Set 5 | shenzhen
# Processing Record 21 of Set 5 | voznesenskaya
# Processing Record 22 of Set 5 | hofn
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | aktyubinskiy
# Processing Record 26 of Set 5 | srednekolymsk
# Processing Record 27 of Set 5 | santa lucia
# Processing Record 28 of Set 5 | narsaq
# Processing Record 29 of Set 5 | husavik
# Processing Record 30 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 5 | lerwick
# Processing Record 32 of Set 5 | rio gallegos
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | rawson
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | plattsburgh
# Processing Record 37 of Set 5 | vanavara
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | urucara
# Processing Record 41 of Set 5 | progreso
# Processing Record 42 of Set 5 | pontarlier
# Processing Record 43 of Set 5 | juneau
# Processing Record 44 of Set 5 | awjilah
# Processing Record 45 of Set 5 | altos
# Processing Record 46 of Set 5 | udachnyy
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | namibe
# Processing Record 49 of Set 5 | chlorakas
# Processing Record 50 of Set 5 | killybegs
# Processing Record 1 of Set 6 | lieksa
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | puerto leguizamo
# Processing Record 4 of Set 6 | saint-philippe
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | portree
# Processing Record 7 of Set 6 | mitu
# Processing Record 8 of Set 6 | urengoy
# Processing Record 9 of Set 6 | dunedin
# Processing Record 10 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 6 | yeppoon
# Processing Record 12 of Set 6 | kununurra
# Processing Record 13 of Set 6 | rancho palos verdes
# Processing Record 14 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 6 | vikhorevka
# Processing Record 16 of Set 6 | urumqi
# Processing Record 17 of Set 6 | tiarei
# Processing Record 18 of Set 6 | shuyskoye
# Processing Record 19 of Set 6 | dong hoi
# Processing Record 20 of Set 6 | wooster
# Processing Record 21 of Set 6 | abu kamal
# Processing Record 22 of Set 6 | bria
# Processing Record 23 of Set 6 | nouadhibou
# Processing Record 24 of Set 6 | seymchan
# Processing Record 25 of Set 6 | cascais
# Processing Record 26 of Set 6 | adjumani
# Processing Record 27 of Set 6 | nyurba
# Processing Record 28 of Set 6 | atambua
# Processing Record 29 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 6 | ati
# Processing Record 31 of Set 6 | banjar
# Processing Record 32 of Set 6 | yovon
# Processing Record 33 of Set 6 | san carlos
# Processing Record 34 of Set 6 | huanren
# Processing Record 35 of Set 6 | ambilobe
# Processing Record 36 of Set 6 | fort nelson
# Processing Record 37 of Set 6 | port lincoln
# Processing Record 38 of Set 6 | clarence town
# Processing Record 39 of Set 6 | chegdomyn
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | tias
# Processing Record 42 of Set 6 | gat
# Processing Record 43 of Set 6 | santa cruz del norte
# Processing Record 44 of Set 6 | tautira
# Processing Record 45 of Set 6 | ndele
# Processing Record 46 of Set 6 | zaraza
# Processing Record 47 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 6 | togul
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | la asuncion
# Processing Record 1 of Set 7 | ahipara
# Processing Record 2 of Set 7 | port hawkesbury
# Processing Record 3 of Set 7 | fallon
# Processing Record 4 of Set 7 | la ronge
# Processing Record 5 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 7 | chokwe
# Processing Record 7 of Set 7 | ostersund
# Processing Record 8 of Set 7 | morondava
# Processing Record 9 of Set 7 | tokonou
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | floro
# Processing Record 12 of Set 7 | tomatlan
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | ouro preto do oeste
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | sorkjosen
# Processing Record 17 of Set 7 | luderitz
# Processing Record 18 of Set 7 | bandar-e lengeh
# Processing Record 19 of Set 7 | nalut
# Processing Record 20 of Set 7 | cuitareo
# Processing Record 21 of Set 7 | yabrud
# Processing Record 22 of Set 7 | lasa
# Processing Record 23 of Set 7 | turan
# Processing Record 24 of Set 7 | cabo san lucas
# Processing Record 25 of Set 7 | ulaanbaatar
# Processing Record 26 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 7 | pedernales
# Processing Record 28 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 7 | marinette
# Processing Record 30 of Set 7 | bowen
# Processing Record 31 of Set 7 | russell
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | lake city
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | puerto escondido
# Processing Record 36 of Set 7 | mtimbira
# Processing Record 37 of Set 7 | saint-joseph
# Processing Record 38 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 7 | beira
# Processing Record 40 of Set 7 | atherton
# Processing Record 41 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 7 | karratha
# Processing Record 44 of Set 7 | cap malheureux
# Processing Record 45 of Set 7 | tilichiki
# Processing Record 46 of Set 7 | dezhou
# Processing Record 47 of Set 7 | mooi river
# City not found. Skipping...
# Processing Record 48 of Set 7 | camopi
# Processing Record 49 of Set 7 | contamana
# Processing Record 50 of Set 7 | detva
# Processing Record 1 of Set 8 | nanortalik
# Processing Record 2 of Set 8 | sawtell
# Processing Record 3 of Set 8 | dayong
# Processing Record 4 of Set 8 | san cristobal
# Processing Record 5 of Set 8 | taunggyi
# Processing Record 6 of Set 8 | sisimiut
# Processing Record 7 of Set 8 | moree
# Processing Record 8 of Set 8 | ekpoma
# Processing Record 9 of Set 8 | leningradskiy
# Processing Record 10 of Set 8 | teguldet
# Processing Record 11 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 8 | greytown
# Processing Record 13 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 8 | malartic
# Processing Record 15 of Set 8 | kavieng
# Processing Record 16 of Set 8 | saint-augustin
# Processing Record 17 of Set 8 | timberlake
# Processing Record 18 of Set 8 | burica
# City not found. Skipping...
# Processing Record 19 of Set 8 | bazum
# Processing Record 20 of Set 8 | hornepayne
# Processing Record 21 of Set 8 | osmena
# Processing Record 22 of Set 8 | nadym
# Processing Record 23 of Set 8 | mayo
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | promyshlennovskiy
# Processing Record 26 of Set 8 | marmashen
# Processing Record 27 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 8 | general roca
# Processing Record 29 of Set 8 | dehui
# Processing Record 30 of Set 8 | sauda
# Processing Record 31 of Set 8 | prince george
# Processing Record 32 of Set 8 | playas
# Processing Record 33 of Set 8 | severnyy
# Processing Record 34 of Set 8 | staryy nadym
# Processing Record 35 of Set 8 | biysk
# Processing Record 36 of Set 8 | wilmington
# Processing Record 37 of Set 8 | male
# Processing Record 38 of Set 8 | quatre cocos
# Processing Record 39 of Set 8 | tasiilaq
# Processing Record 40 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 8 | naron
# Processing Record 42 of Set 8 | port macquarie
# Processing Record 43 of Set 8 | villa rica
# Processing Record 44 of Set 8 | calama
# Processing Record 45 of Set 8 | matagami
# Processing Record 46 of Set 8 | lagos
# Processing Record 47 of Set 8 | usinsk
# Processing Record 48 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 8 | sitka
# Processing Record 50 of Set 8 | tuatapere
# Processing Record 1 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 9 | cap-aux-meules
# Processing Record 3 of Set 9 | araouane
# Processing Record 4 of Set 9 | kloulklubed
# Processing Record 5 of Set 9 | cabedelo
# Processing Record 6 of Set 9 | kusti
# Processing Record 7 of Set 9 | ko samui
# Processing Record 8 of Set 9 | sept-iles
# Processing Record 9 of Set 9 | amarpatan
# Processing Record 10 of Set 9 | bjerringbro
# Processing Record 11 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 9 | martapura
# Processing Record 13 of Set 9 | beaune
# Processing Record 14 of Set 9 | mushie
# Processing Record 15 of Set 9 | tobermory
# Processing Record 16 of Set 9 | diffa
# Processing Record 17 of Set 9 | plettenberg bay
# Processing Record 18 of Set 9 | pulaski
# Processing Record 19 of Set 9 | san patricio
# Processing Record 20 of Set 9 | piacabucu
# Processing Record 21 of Set 9 | chunskiy
# Processing Record 22 of Set 9 | dicabisagan
# Processing Record 23 of Set 9 | monatele
# City not found. Skipping...
# Processing Record 24 of Set 9 | ambanja
# Processing Record 25 of Set 9 | nola
# Processing Record 26 of Set 9 | williams lake
# Processing Record 27 of Set 9 | karakose
# City not found. Skipping...
# Processing Record 28 of Set 9 | ilulissat
# Processing Record 29 of Set 9 | gorontalo
# Processing Record 30 of Set 9 | bara
# Processing Record 31 of Set 9 | viedma
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | arenzano
# Processing Record 34 of Set 9 | ossora
# Processing Record 35 of Set 9 | vyartsilya
# Processing Record 36 of Set 9 | jevnaker
# Processing Record 37 of Set 9 | antofagasta
# Processing Record 38 of Set 9 | kousseri
# Processing Record 39 of Set 9 | cagliliog
# Processing Record 40 of Set 9 | kavaratti
# Processing Record 41 of Set 9 | olafsvik
# Processing Record 42 of Set 9 | dingzhou
# Processing Record 43 of Set 9 | qui nhon
# Processing Record 44 of Set 9 | conde
# Processing Record 45 of Set 9 | norman wells
# Processing Record 46 of Set 9 | vilhena
# Processing Record 47 of Set 9 | oranjestad
# Processing Record 48 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 9 | broome
# Processing Record 50 of Set 9 | kupang
# Processing Record 1 of Set 10 | sobolevo
# Processing Record 2 of Set 10 | nizhyn
# Processing Record 3 of Set 10 | verkh-usugli
# Processing Record 4 of Set 10 | derzhavinsk
# Processing Record 5 of Set 10 | pangnirtung
# Processing Record 6 of Set 10 | barber
# Processing Record 7 of Set 10 | rambha
# Processing Record 8 of Set 10 | knysna
# Processing Record 9 of Set 10 | portland
# Processing Record 10 of Set 10 | fez
# Processing Record 11 of Set 10 | bethanien
# Processing Record 12 of Set 10 | koungou
# Processing Record 13 of Set 10 | grindavik
# Processing Record 14 of Set 10 | hays
# Processing Record 15 of Set 10 | chifeng
# Processing Record 16 of Set 10 | springdale
# Processing Record 17 of Set 10 | megion
# Processing Record 18 of Set 10 | ponta delgada
# Processing Record 19 of Set 10 | thunder bay
# Processing Record 20 of Set 10 | sitio novo do tocantins
# Processing Record 21 of Set 10 | eyl
# Processing Record 22 of Set 10 | abashiri
# Processing Record 23 of Set 10 | ketchikan
# Processing Record 24 of Set 10 | fayaoue
# Processing Record 25 of Set 10 | padang
# Processing Record 26 of Set 10 | diamantina
# Processing Record 27 of Set 10 | adelaide
# Processing Record 28 of Set 10 | biratnagar
# Processing Record 29 of Set 10 | chimbote
# Processing Record 30 of Set 10 | baniachang
# Processing Record 31 of Set 10 | vozhega
# Processing Record 32 of Set 10 | banfora
# Processing Record 33 of Set 10 | palasa
# Processing Record 34 of Set 10 | ugento
# Processing Record 35 of Set 10 | isangel
# Processing Record 36 of Set 10 | mehamn
# Processing Record 37 of Set 10 | ouallam
# Processing Record 38 of Set 10 | mercedes
# Processing Record 39 of Set 10 | vila franca do campo
# Processing Record 40 of Set 10 | mountrath
# Processing Record 41 of Set 10 | dankov
# Processing Record 42 of Set 10 | kukuna
# Processing Record 43 of Set 10 | montmagny
# Processing Record 44 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 10 | galle
# Processing Record 46 of Set 10 | lujan
# Processing Record 47 of Set 10 | peru
# Processing Record 48 of Set 10 | micheweni
# Processing Record 49 of Set 10 | ilinskiy
# Processing Record 50 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 11 | talcahuano
# Processing Record 2 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 11 | isabela
# Processing Record 4 of Set 11 | pevek
# Processing Record 5 of Set 11 | miramar
# Processing Record 6 of Set 11 | lichinga
# Processing Record 7 of Set 11 | gijon
# Processing Record 8 of Set 11 | kebumen
# Processing Record 9 of Set 11 | kruisfontein
# Processing Record 10 of Set 11 | alencon
# Processing Record 11 of Set 11 | kaeo
# Processing Record 12 of Set 11 | black river
# Processing Record 13 of Set 11 | cocobeach
# Processing Record 14 of Set 11 | sungairaya
# Processing Record 15 of Set 11 | jiayuguan
# Processing Record 16 of Set 11 | sinnamary
# Processing Record 17 of Set 11 | gilazi
# City not found. Skipping...
# Processing Record 18 of Set 11 | san luis
# Processing Record 19 of Set 11 | clyde river
# Processing Record 20 of Set 11 | karibib
# Processing Record 21 of Set 11 | manavalakurichi
# Processing Record 22 of Set 11 | belmonte
# Processing Record 23 of Set 11 | boulder
# Processing Record 24 of Set 11 | goudomp
# City not found. Skipping...
# Processing Record 25 of Set 11 | severo-yeniseyskiy
# Processing Record 26 of Set 11 | san felipe
# Processing Record 27 of Set 11 | alakurtti
# Processing Record 28 of Set 11 | oussouye
# Processing Record 29 of Set 11 | buin
# Processing Record 30 of Set 11 | senneterre
# Processing Record 31 of Set 11 | lodja
# Processing Record 32 of Set 11 | harper
# Processing Record 33 of Set 11 | ulaangom
# Processing Record 34 of Set 11 | katangli
# Processing Record 35 of Set 11 | whitianga
# Processing Record 36 of Set 11 | ormara
# Processing Record 37 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 11 | hay river
# Processing Record 39 of Set 11 | bhinmal
# Processing Record 40 of Set 11 | buraydah
# Processing Record 41 of Set 11 | buala
# Processing Record 42 of Set 11 | inhambane
# Processing Record 43 of Set 11 | pachino
# Processing Record 44 of Set 11 | port keats
# Processing Record 45 of Set 11 | janakkala
# Processing Record 46 of Set 11 | azangaro
# Processing Record 47 of Set 11 | san rafael
# Processing Record 48 of Set 11 | santa barbara
# Processing Record 49 of Set 11 | kyakhta
# Processing Record 50 of Set 11 | umm lajj
# Processing Record 1 of Set 12 | north bend
# Processing Record 2 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 12 | kudahuvadhoo
# Processing Record 4 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 12 | mulanje
# Processing Record 6 of Set 12 | whyalla
# Processing Record 7 of Set 12 | marzuq
# Processing Record 8 of Set 12 | korcula
# Processing Record 9 of Set 12 | halifax
# Processing Record 10 of Set 12 | sheregesh
# Processing Record 11 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 12 | avera
# Processing Record 13 of Set 12 | linhares
# Processing Record 14 of Set 12 | tiete
# Processing Record 15 of Set 12 | marapanim
# Processing Record 16 of Set 12 | kibaya
# Processing Record 17 of Set 12 | araguaina
# Processing Record 18 of Set 12 | kjollefjord
# Processing Record 19 of Set 12 | paamiut
# Processing Record 20 of Set 12 | waipawa
# Processing Record 21 of Set 12 | mahon
# Processing Record 22 of Set 12 | kargopol
# Processing Record 23 of Set 12 | manuel doblado
# City not found. Skipping...
# Processing Record 24 of Set 12 | deputatskiy
# Processing Record 25 of Set 12 | kysyl-syr
# Processing Record 26 of Set 12 | alto araguaia
# Processing Record 27 of Set 12 | berdigestyakh
# Processing Record 28 of Set 12 | auki
# Processing Record 29 of Set 12 | beyneu
# Processing Record 30 of Set 12 | turayf
# Processing Record 31 of Set 12 | pangody
# Processing Record 32 of Set 12 | krutaya gorka
# Processing Record 33 of Set 12 | pong
# Processing Record 34 of Set 12 | sterling
# Processing Record 35 of Set 12 | nome
# Processing Record 36 of Set 12 | coquimbo
# Processing Record 37 of Set 12 | namatanai
# Processing Record 38 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | eureka
# Processing Record 40 of Set 12 | sapao
# City not found. Skipping...
# Processing Record 41 of Set 12 | coahuayana
# Processing Record 42 of Set 12 | ngunguru
# Processing Record 43 of Set 12 | tateyama
# Processing Record 44 of Set 12 | balangiga
# Processing Record 45 of Set 12 | visaginas
# Processing Record 46 of Set 12 | wala
# Processing Record 47 of Set 12 | paragominas
# Processing Record 48 of Set 12 | visnes
# Processing Record 49 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 12 | gallup
# Processing Record 1 of Set 13 | tawau
# Processing Record 2 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 13 | kamaishi
# Processing Record 4 of Set 13 | ternate
# Processing Record 5 of Set 13 | disna
# Processing Record 6 of Set 13 | jasper
# Processing Record 7 of Set 13 | presidencia roque saenz pena
# Processing Record 8 of Set 13 | teya
# Processing Record 9 of Set 13 | christchurch
# Processing Record 10 of Set 13 | ozernovskiy
# Processing Record 11 of Set 13 | krasnoarmeysk
# Processing Record 12 of Set 13 | xining
# Processing Record 13 of Set 13 | odzun
# Processing Record 14 of Set 13 | emerald
# Processing Record 15 of Set 13 | zabaykalsk
# Processing Record 16 of Set 13 | banda aceh
# Processing Record 17 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 18 of Set 13 | nishihara
# Processing Record 19 of Set 13 | humberto de campos
# Processing Record 20 of Set 13 | tabora
# Processing Record 21 of Set 13 | new ulm
# Processing Record 22 of Set 13 | nantucket
# Processing Record 23 of Set 13 | henties bay
# Processing Record 24 of Set 13 | pizhma
# Processing Record 25 of Set 13 | nueve de julio
# Processing Record 26 of Set 13 | pasir gudang
# Processing Record 27 of Set 13 | goya
# Processing Record 28 of Set 13 | thinadhoo
# Processing Record 29 of Set 13 | pinar del rio
# Processing Record 30 of Set 13 | kostalexis
# Processing Record 31 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 32 of Set 13 | sokur
# Processing Record 33 of Set 13 | constantine
# Processing Record 34 of Set 13 | linshu
# City not found. Skipping...
# Processing Record 35 of Set 13 | cabras
# Processing Record 36 of Set 13 | egvekinot
# Processing Record 37 of Set 13 | guanare
# Processing Record 38 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 13 | sunyani
# Processing Record 40 of Set 13 | omboue
# Processing Record 41 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 42 of Set 13 | tambura
# Processing Record 43 of Set 13 | verkhoyansk
# Processing Record 44 of Set 13 | merritt
# Processing Record 45 of Set 13 | jupiter
# Processing Record 46 of Set 13 | livramento
# Processing Record 47 of Set 13 | mudgee
# Processing Record 48 of Set 13 | palmer
# Processing Record 49 of Set 13 | tuyen quang
# Processing Record 50 of Set 13 | maragogi
# Processing Record 1 of Set 14 | san jose
# Processing Record 2 of Set 14 | vestmannaeyjar
# Processing Record 3 of Set 14 | manoel urbano
# Processing Record 4 of Set 14 | dukat
# Processing Record 5 of Set 14 | kungurtug
# Processing Record 6 of Set 14 | georgiyevka
# Processing Record 7 of Set 14 | makakilo city
# Processing Record 8 of Set 14 | agadez
# Processing Record 9 of Set 14 | ambon
# Processing Record 10 of Set 14 | vetlanda
# Processing Record 11 of Set 14 | athieme
# City not found. Skipping...
# Processing Record 12 of Set 14 | stornoway
# Processing Record 13 of Set 14 | atar
# Processing Record 14 of Set 14 | belfast
# Processing Record 15 of Set 14 | nabire
# Processing Record 16 of Set 14 | morro agudo
# Processing Record 17 of Set 14 | huarmey
# Processing Record 18 of Set 14 | bambanglipuro
# Processing Record 19 of Set 14 | charters towers
# Processing Record 20 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 14 | ostrovnoy
# Processing Record 22 of Set 14 | trincomalee
# Processing Record 23 of Set 14 | san lazaro
# Processing Record 24 of Set 14 | camocim
# Processing Record 25 of Set 14 | wuhu
# Processing Record 26 of Set 14 | turukhansk
# Processing Record 27 of Set 14 | doha
# Processing Record 28 of Set 14 | sarangani
# Processing Record 29 of Set 14 | zyryanka
# Processing Record 30 of Set 14 | bonavista
# Processing Record 31 of Set 14 | riyadh
# Processing Record 32 of Set 14 | cherepanovo
# Processing Record 33 of Set 14 | san jeronimo
# Processing Record 34 of Set 14 | kobelyaky
# Processing Record 35 of Set 14 | voh
# Processing Record 36 of Set 14 | bilibino
# Processing Record 37 of Set 14 | half moon bay
# Processing Record 38 of Set 14 | hamilton
# Processing Record 39 of Set 14 | krasnyy chikoy
# Processing Record 40 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 41 of Set 14 | iskateley
# Processing Record 42 of Set 14 | alofi
# Processing Record 43 of Set 14 | yumen
# Processing Record 44 of Set 14 | plouzane
# Processing Record 45 of Set 14 | panjab
# Processing Record 46 of Set 14 | nicoya
# Processing Record 47 of Set 14 | casablanca
# Processing Record 48 of Set 14 | greven
# Processing Record 49 of Set 14 | evensk
# Processing Record 50 of Set 14 | edd
# Processing Record 1 of Set 15 | okhotsk
# Processing Record 2 of Set 15 | la rioja
# Processing Record 3 of Set 15 | ada
# Processing Record 4 of Set 15 | acari
# Processing Record 5 of Set 15 | ushtobe
# Processing Record 6 of Set 15 | leo
# Processing Record 7 of Set 15 | navalgund
# Processing Record 8 of Set 15 | ugra
# Processing Record 9 of Set 15 | adra
# Processing Record 10 of Set 15 | bud
# Processing Record 11 of Set 15 | cimarron hills
# Processing Record 12 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 15 | iquique
# Processing Record 14 of Set 15 | esquipulas palo gordo
# Processing Record 15 of Set 15 | aksarka
# Processing Record 16 of Set 15 | hailar
# Processing Record 17 of Set 15 | rocha
# Processing Record 18 of Set 15 | saint-francois
# Processing Record 19 of Set 15 | synya
# Processing Record 20 of Set 15 | kosh-agach
# Processing Record 21 of Set 15 | gongzhuling
# Processing Record 22 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 15 | poum
# Processing Record 24 of Set 15 | soyo
# Processing Record 25 of Set 15 | fukue
# Processing Record 26 of Set 15 | oistins
# Processing Record 27 of Set 15 | rudnyy
# Processing Record 28 of Set 15 | chernushka
# Processing Record 29 of Set 15 | lazaro cardenas
# Processing Record 30 of Set 15 | saint cyrus
# City not found. Skipping...
# Processing Record 31 of Set 15 | pochutla
# Processing Record 32 of Set 15 | ishigaki
# Processing Record 33 of Set 15 | dwarka
# Processing Record 34 of Set 15 | wuwei
# Processing Record 35 of Set 15 | redcliffe
# Processing Record 36 of Set 15 | sarh
# Processing Record 37 of Set 15 | douglas
# Processing Record 38 of Set 15 | pontian kecil
# Processing Record 39 of Set 15 | ust-tsilma
# Processing Record 40 of Set 15 | plotnikovo
# Processing Record 41 of Set 15 | teknaf
# Processing Record 42 of Set 15 | santiago
# Processing Record 43 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 15 | chapais
# Processing Record 45 of Set 15 | pindwara
# Processing Record 46 of Set 15 | umm kaddadah
# Processing Record 47 of Set 15 | alekseyevka
# Processing Record 48 of Set 15 | arlit
# Processing Record 49 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 15 | maulvi bazar
# City not found. Skipping...
# Processing Record 1 of Set 16 | ozgon
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro -24.7911  -50.0119     64.49        75          28
# 1  Ornskoldsvik  63.2909   18.7153     32.00        80          20
# 2     Mahebourg -20.4081   57.7000     77.00        94          75
# 3        Kaseda  31.4167  130.3167     54.52        67           0
# 4          Hovd  48.0056   91.6419     47.21        41          65
# 5       Mataura -46.1927  168.8643     43.70        89           0
# 6       Margate  51.3813    1.3862     44.01        79           5
# 7  Saint George  37.1041 -113.5841     79.00         9           1
# 8          Poya -21.3500  165.1500     75.65        90          50
# 9  Punta Arenas -53.1500  -70.9167     53.60        54          20
#
#    Wind Speed Current Description
# 0        5.48    scattered clouds
# 1        1.14          few clouds
# 2       10.27          light rain
# 3        6.87           clear sky
# 4       13.24       broken clouds
# 5        3.44           clear sky
# 6        1.01           clear sky
# 7       12.66           clear sky
# 8        4.50    scattered clouds
# 9       17.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
