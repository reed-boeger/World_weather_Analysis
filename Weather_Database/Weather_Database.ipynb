# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from config import weather_api_key
from citipy import citipy
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
#testing
london_data = []
england = "london"
london_url = "http://api.openweathermap.org/data/2.5/weather?q=" + england + "&units=imperial" + "&appid=" + weather_api_key

london_weather = requests.get(london_url).json()
london_weather
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 39.49,
#   'feels_like': 35.31,
#   'temp_min': 37,
#   'temp_max': 41,
#   'pressure': 1026,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 50},
#  'clouds': {'all': 8},
#  'dt': 1619053923,
#  'sys': {'type': 1,
#   'id': 1414,
#   'country': 'GB',
#   'sunrise': 1619066978,
#   'sunset': 1619118478},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
#finally found index method for description
london_data = []
england = "london"
london_url = "http://api.openweathermap.org/data/2.5/weather?q=" + england + "&units=imperial" + "&appid=" + weather_api_key

london_weather = requests.get(london_url).json()

london_lat = london_weather["coord"]["lat"]
london_id = london_weather["weather"][0]["description"]
london_id
# Out:
# 'clear sky'

# %%
#testing
london_data = []
england = "london"
london_url = "http://api.openweathermap.org/data/2.5/weather?q=" + england + "&units=imperial" + "&appid=" + weather_api_key

london_weather = requests.get(london_url).json()

london_lat = london_weather["coord"]["lat"]
#city_lng = city_weather["coord"]["lon"]
london_max_temp = london_weather["main"]["temp_max"]
#city_humidity = city_weather["main"]["humidity"]
#city_clouds = city_weather["clouds"]["all"]
#city_wind = city_weather["wind"]["speed"]
london_description = london_weather["weather"][0]["description"]

print(london_lat)

london_data.append({"City": "London",
                    "Lat": london_lat,
                    "Max Temp": london_max_temp,
                    "Weather Description": london_description})
london_data
# Out:
# 51.5085
# [{'City': 'London',
#   'Lat': 51.5085,
#   'Max Temp': 41,
#   'Weather Description': 'clear sky'}]

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = "http://api.openweathermap.org/data/2.5/weather?q=" + city.replace(" ", "+") + "&units=imperial" + "&appid=" + weather_api_key

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
   
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | boca do acre
# Processing Record 2 of Set 1 | nanortalik
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | veraval
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | eganville
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | geraldton
# Processing Record 12 of Set 1 | laguna
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | pizhanka
# Processing Record 16 of Set 1 | nabire
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | yaan
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | vaitupu
# ...

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Boca Do Acre      BR  -8.7522  -67.3978     73.18        97          65
# 1    Nanortalik      GL  60.1432  -45.2371     36.70        77         100
# 2        Albany      US  42.6001  -73.9662     36.00        58          40
# 3         Kapaa      US  22.0752 -159.3190     78.01        83          90
# 4       Veraval      IN  20.9000   70.3667     77.86        78         100
# 5          Lebu      CL -37.6167  -73.6500     53.58        82          35
# 6     Eganville      CA  45.5334  -77.0994     32.00        40          90
# 7       Ushuaia      AR -54.8000  -68.3000     44.60        57           0
# 8     Geraldton      AU -28.7667  114.6000     73.40        38          92
# 9        Laguna      US  38.4210 -121.4238     75.00        35           1
#
#    Wind Speed Current Description
# 0        1.70       broken clouds
# 1        4.59     overcast clouds
# 2        1.99    scattered clouds
# ...

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
